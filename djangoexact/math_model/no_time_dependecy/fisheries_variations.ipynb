# %%
from fisheries_and_aquaculture_parameter_based import total_emissions_small_or_large_fisheries as total_emissions_parameter_based
from fisheries_and_aquaculture_as_excel import total_emissions_small_or_large_fisheries as total_emissions_excel
from fisheries_and_aquaculture_delta_yearly import total_emissions_small_or_large_fisheries as total_emissions_delta_yearly

# %%
param = total_emissions_parameter_based(20, 9, 0.5, 0.5, 500, 450, 1000, 2.572333333334, None, 671, 73, 45, 73, 1810, None, 0.083, None, 0.5, 0.5, 0.5, 2.8, None, 60, None, 0.573978947, 0.5, 0.8, 0.5)
excel = total_emissions_excel(20, 9, 0.5, 0.5, 500, 450, 1000, 2.572333333334, None, 671, 73, 45, 73, 1810, None, 0.083, None, 0.5, 0.5, 0.5, 2.8, None, 60, None, 0.573978947, 0.5, 0.8, 0.5)
delta = total_emissions_delta_yearly(20, 9, 0.5, 0.5, 500, 450, 1000, 2.572333333334, None, 671, 73, 45, 73, 1810, None, 0.083, None, 0.5, 0.5, 0.5, 2.8, None, 60, None, 0.573978947, 0.5, 0.8, 0.5)
